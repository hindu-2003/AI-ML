# %%
import array
arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
math.sqrt(16)
math.pi
# Out:
# 3.141592653589793

# %%
## random
import random
random.randint(1,10)
random.choice(['mahesh','suresh','rakesh'])
# Out:
# 'suresh'

# %%
## File Directory Access
import os
os.mkdir("Folder Name")

os.getcwd()
# Out:
# 'd:\\My\\PRO\\PYTHON\\PYTHON LIBRARIES'
