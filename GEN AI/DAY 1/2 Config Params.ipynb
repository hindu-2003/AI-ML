# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyCpr-0BTbKdVfWKtf6gub2orlGhDYwxKmI")

# %%
flash = genai.GenerativeModel('gemini-2.5-flash')

# %%
response = flash.generate_content("Explain AI to me like I'm a kid.")

print(response.text)
# Out:
# Okay, imagine your favorite toy or even a computer game character.
#
# Now, imagine if that toy or character could **think and learn**, almost like you do!
#
# That's kind of what **AI** (which stands for Artificial Intelligence) is!
#
# Think of it like this:
#
# 1.  **A Super Smart Brain for Computers:** AI gives computers a special "brain" that can learn things.
# 2.  **Learning Like You Do:**
#     *   When you learn what a dog looks like, your parents show you lots of pictures of dogs, right? And you learn to tell the difference between a dog and a cat.
#     *   Well, we can show an AI computer **millions of pictures of dogs**, and it learns to spot a dog all by itself!
#     *   Or we can teach it to play a game, and it learns the rules and gets better and better, just like you do when you practice.
#
# **What does this super smart computer brain *do*?**
#
# *   **It can listen:** When you talk to a smart speaker like Alexa or Google Home, AI helps it understand what you're saying and find the answers.
# *   **It can see:** When your parent's phone unlocks just by looking at their face, AI helps the phone "see" and recognize who they are.
# *   **It can help you find things:** When a website suggests a new toy or a movie you might like, because it knows what you've liked before, that's AI figuring out what you might enjoy.
# *   **It can drive cars (sometimes!):** Imagine a car that can drive itself, knowing when to stop at a red light or turn a corner. That's AI helping the car "see" the road and make decisions.
# *   **It helps in games:** In some video games, the other players who aren't real people are often using AI to know how to play against you.
#
# **So, AI is like making computers into very clever helpers that can learn things and solve problems, almost like they're thinking.**
#
# It doesn't have feelings or get tired like you do. It's not a real person or a magic monster. It's just a very clever tool made by people to help us do amazing things!
#
# Pretty cool, huh?

# %% [markdown]
# ### Storing chat History

# %%
chat = flash.start_chat(history=[])

response = chat.send_message('Hello! My name is Dr Ganapathi Raju.')
print(response.text)
# Out:
# Hello, Dr. Ganapathi Raju! It's a pleasure to meet you.
#
# How can I assist you today?

# %%
response = chat.send_message('Can you tell something interesting about Gen AI?')
print(response.text)
# Out:
# Hello, Dr. Ganapathi Raju! It's a fascinating request, as Gen AI is truly one of the most exciting and rapidly evolving fields right now. Here are a few things I find particularly interesting about it:
#
# 1.  **It's Not Just Smart; It's *Imaginative***: Unlike traditional AI that primarily analyzes, classifies, or predicts based on existing data, Generative AI *creates* something new. It can write poems, compose music, design images from text descriptions, generate realistic faces, and even write code. It's moving from "understanding" to "imagining" (in a statistical sense, of course).
#
# 2.  **The "Emergent Properties" are Wild**: Sometimes, Gen AI models demonstrate capabilities that weren't explicitly programmed or even anticipated by their creators. For example, large language models can perform complex reasoning tasks, translate between languages, or even debug code, not because they were specifically trained for these tasks, but because their vast exposure to data allowed these abilities to *emerge*. It's like a digital "aha!" moment.
#
# 3.  **It's a Super-Collaborator, Not Just a Tool**: Think of it less as an automation tool and more as a creative partner. An artist can use it to generate initial concepts or variations, a writer to overcome writer's block or brainstorm ideas, a coder to complete functions, or a musician to create new melodies. It augments human potential rather than just replacing manual labor.
#
# 4.  **Mimicry Without Understanding (Yet?)**: One of the most mind-bending aspects is that these models can produce incredibly human-like outputs – text, images, speech – without truly "understanding" the world, consciousness, or emotions in the way humans do. They operate on complex statistical patterns learned from vast datasets. This raises profound philosophical questions about intelligence, creativity, and consciousness itself.
#
# 5.  **Accelerating Discovery Across Fields**: Beyond creative arts, Gen AI is rapidly being applied to scientific discovery. It can design novel proteins for medicine, optimize material properties, or even generate new hypotheses in research. This ability to rapidly explore vast possibility spaces could dramatically speed up innovation in chemistry, biology, and physics.
#
# 6.  **The Blurring Lines of "Originality" and "Authorship"**: When an AI generates a stunning piece of art or a compelling story, who is the author? Is it the AI, the human who prompted it, or the original creators of the training data? This field is forcing us to redefine our understanding of creativity and ownership in the digital age, leading to new ethical, legal, and artistic debates.
#
# Gen AI is not just a technological advancement; it's a cultural, philosophical, and economic earthquake in the making. We're truly just scratching the surface of what's possible!

# %%
response = chat.send_message('Do you remember what my name is?')
print(response.text)
# Out:
# Yes, I do! Your name is Dr. Ganapathi Raju.

# %% [markdown]
# ### Choose a model
#
# The Gemini API provides access to a number of models from the Gemini model family.

# %%
for model in genai.list_models():
  print(model.name)
# Out:
# models/embedding-gecko-001
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/gemini-embedding-001
# models/aqa
# models/imagen-4.0-generate-preview-06-06
# models/imagen-4.0-ultra-generate-preview-06-06
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/gemini-2.0-flash-live-001
# models/gemini-live-2.5-flash-preview
# models/gemini-2.5-flash-live-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025

# %% [markdown]
# The [`models.list`](https://ai.google.dev/api/models#method:-models.list) response also returns additional information about the model's capabilities, like the token limits and supported parameters.

# %%
for model in genai.list_models():
  if model.name == 'models/gemini-2.5-flash':
    print(model)
    break
# Out:
# Model(name='models/gemini-2.5-flash',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 2.5 Flash',
#       description=('Stable version of Gemini 2.5 Flash, our mid-size multimodal model that '
#                    'supports up to 1 million tokens, released in June of 2025.'),
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent',
#                                     'countTokens',
#                                     'createCachedContent',
#                                     'batchGenerateContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)

# %% [markdown]
# ## Explore generation parameters

# %% [markdown]
# ### Output length
#
# When generating text with an LLM, the output length affects cost and performance.
#
# Generating more tokens increases computation, leading to higher energy consumption, latency, and cost.
#
# To stop the model from generating tokens past a limit, you can specify the `max_output_tokens` parameter when using the Gemini API.
#
# Specifying this parameter does not influence the generation of the output tokens, so the output will not become more stylistically or textually succinct, but it will stop generating tokens once the specified length is reached.
#
# Prompt engineering may be required to generate a more complete output for your given limit.

# %% [markdown]
# short_model = genai.GenerativeModel(
#     'gemini-2.5-flash',
#     generation_config=genai.GenerationConfig(max_output_tokens=200))
#
# response = short_model.generate_content('Write a 100 word essay on the importance of Gen AI modern society.')
# print(response.text)

# %%
import google.generativeai as genai
print(genai.__version__)
# Out:
# 0.8.5

# %% [markdown]
# ### Temperature
#
# Temperature controls the degree of randomness in token selection.
#
# Higher temperatures result in a higher number of candidate tokens from which the next output token is selected, and can produce more diverse results, while lower temperatures have the opposite effect, such that a temperature of 0 results in greedy decoding, selecting the most probable token at each step.
#
# Temperature doesn't provide any guarantees of randomness, but it can be used to "nudge" the output somewhat.

# %%
import google.generativeai as genai

# Create model with higher temperature (more randomness)
high_temp_model = genai.GenerativeModel(
    "gemini-2.5-flash",
    generation_config=genai.GenerationConfig(temperature=2.0)
)

for _ in range(5):
    response = high_temp_model.generate_content(
        "Pick a random colour... (respond in a single word)",
    )
    print(response.text, "-" * 25)
# Out:
# Blue -------------------------
# Green -------------------------
# Blue -------------------------
# Blue -------------------------
# Blue -------------------------

# %% [markdown]
# Now try the same prompt with temperature set to zero.
#
# Note that the output is not completely deterministic, as other parameters affect token selection, but the results will tend to be more stable.

# %% [markdown]
# https://www.youtube.com/watch?v=aDmp2Uim0zQ

# %% [markdown]
# ### Top-K and top-P
#
# Like temperature, top-K and top-P parameters are also used to control the diversity of the model's output.
#
# Top-K is a positive integer that defines the number of most probable tokens from which to select the output token.
#
# A top-K of 1 selects a single token, performing greedy decoding.
#
# Top-P defines the probability threshold that, once cumulatively exceeded, tokens stop being selected as candidates.
#
# A top-P of 0 is typically equivalent to greedy decoding, and a top-P of 1 typically selects every token in the model's vocabulary.
#
# When both are supplied, the Gemini API will filter top-K tokens first, then top-P and then finally sample from the candidate tokens using the supplied temperature.
#
# Run this example a number of times, change the settings and observe the change in output.

# %%
model = genai.GenerativeModel(
    'gemini-2.5-flash',
    generation_config=genai.GenerationConfig(
    
        temperature=1.0,
        top_k=64,
        top_p=0.95,
    ))

story_prompt = "You are a creative writer. Write a short story about a cat who goes on an adventure."

response = model.generate_content(story_prompt)
print(response.text)

# %% [markdown]
# ## Prompting
#
# A prompt in AI is a piece of input given to an artificial intelligence (AI) model to produce a specific response.
#
# Prompt engineering is the process of asking the right questions to get the best output from an AI model. It allows for direct interaction with the model using plain language prompts.
#
#
# <b>Shot prompting</b> is a method used in machine learning, with transformer-based models like GPT-3+, to guide the model’s output using a specific number of examples or prompts, known as ‘shots.’
#
# Shot prompting provides three strategies zero-shot, one-shot and few-shot prompting, each involving various examples.
#
# Zero-shot (Direct prompting): No previous data or examples (no shots) are given before completing the request.
#
# One-shot (Prompt by one example): One piece of data or example (1 shot) given before completing the request.
#
# Few-shot (Prompt by multiple examples): Multiple examples or data (Few shots) are given before completing the request.

# %% [markdown]
# ### Zero-shot
#
# Zero-shot prompts are prompts that describe the request for the model directly.
#
# Zero-shot prompting is a machine learning technique that uses an AI model's pre-existing knowledge to perform new tasks without specific training.
#
#
# ##### How it works:
#
# The model is given a task or instruction without any specific examples or guidance
#
# The model uses its pre-trained knowledge to understand and complete the task
#
# The model's general understanding and skills are applied to generate an answer or solution
#
# ##### Examples
# Asking an AI model to identify the capital of France
#
# Asking an AI model to classify the sentiment of a text as positive, negative, or neutral
#
# Asking an AI model to translate a text from one language to another
#
# <table align=left>
#   <td>
#     <a target="_blank" href="https://aistudio.google.com/prompts/1gzKKgDHwkAvexG5Up0LMtl1-6jKMKe4g"><img src="https://ai.google.dev/site-assets/images/marketing/home/icon-ais.png" style="height: 24px" height=24/> Open in AI Studio</a>
#   </td>
# </table>

# %% [markdown]
# #### Enum mode
#
# The models are trained to generate text, and can sometimes produce more text than you may wish for.
#
# In the preceding example, the model will output the label, sometimes it can include a preceding "Sentiment" label, and without an output token limit, it may also add explanatory text afterwards.
#
# The Gemini API has an [Enum mode](https://github.com/google-gemini/cookbook/blob/main/quickstarts/Enum.ipynb) feature that allows you to constrain the output to a fixed set of values.

# %%
import enum

class Sentiment(enum.Enum):
    POSITIVE = "positive"
    NEUTRAL = "neutral"
    NEGATIVE = "negative"


model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(
        response_mime_type="text/x.enum",
        response_schema=Sentiment
    ))

response = model.generate_content(zero_shot_prompt)
print(response.text)

# %% [markdown]
# ### One-shot and few-shot
#
# Providing an example of the expected response is known as a "one-shot" prompt.
#
# When you provide multiple examples, it is a "few-shot" prompt.
#
# <table align=left>
#   <td>
#     <a target="_blank" href="https://aistudio.google.com/prompts/1jjWkjUSoMXmLvMJ7IzADr_GxHPJVV2bg"><img src="https://ai.google.dev/site-assets/images/marketing/home/icon-ais.png" style="height: 24px" height=24/> Open in AI Studio</a>
#   </td>
# </table>

# %%
model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(
        temperature=0.1,
        top_p=1,
        max_output_tokens=250,
    ))

few_shot_prompt = """Parse a customer's pizza order into valid JSON:

EXAMPLE:
I want a small pizza with cheese, tomato sauce, and pepperoni.
JSON Response:
```
{
"size": "small",
"type": "normal",
"ingredients": ["cheese", "tomato sauce", "peperoni"]
}
```

EXAMPLE:
Can I get a large pizza with tomato sauce, basil and mozzarella
JSON Response:
```
{
"size": "large",
"type": "normal",
"ingredients": ["tomato sauce", "basil", "mozzarella"]
}

ORDER:
"""

customer_order = "Give me a large with cheese & pineapple"


response = model.generate_content([few_shot_prompt, customer_order])
print(response.text)

# %% [markdown]
# #### JSON mode
#
# To provide control over the schema, and to ensure that you only receive JSON (with no other text or markdown), you can use the Gemini API's [JSON mode](https://github.com/google-gemini/cookbook/blob/main/quickstarts/JSON_mode.ipynb).
#
# This forces the model to constrain decoding, such that token selection is guided by the supplied schema.

# %%
import typing_extensions as typing

class PizzaOrder(typing.TypedDict):
    size: str
    ingredients: list[str]
    type: str


model = genai.GenerativeModel(
    'gemini-1.5-flash-latest',
    generation_config=genai.GenerationConfig(
        temperature=0.1,
        response_mime_type="application/json",
        response_schema=PizzaOrder,
    ))

response = model.generate_content("Can I have a large dessert pizza with apple and chocolate")
print(response.text)

# %% [markdown]
# ### Chain of Thought (CoT)
#
# Direct prompting on LLMs can return answers quickly and (in terms of output token usage) efficiently, but they can be prone to hallucination.
#
# The answer may "look" correct (in terms of language and syntax) but is incorrect in terms of factuality and reasoning.
#
# Chain-of-Thought prompting is a technique where you instruct the model to output intermediate reasoning steps, and it typically gets better results, especially when combined with few-shot examples.
#
# It is worth noting that this technique doesn't completely eliminate hallucinations, and that it tends to cost more to run, due to the increased token count.
#
# As models like the Gemini family are trained to be "chatty" and provide reasoning steps, you can ask the model to be more direct in the prompt.

# %%
prompt = """When I was 4 years old, my partner was 3 times my age. Now, I
am 20 years old. How old is my partner? Return the answer immediately."""

model = genai.GenerativeModel('gemini-1.5-flash-latest')
response = model.generate_content(prompt)

print(response.text)

# %% [markdown]
# Now try the same approach, but indicate to the model that it should "think step by step".

# %%
prompt = """When I was 4 years old, my partner was 3 times my age. Now,
I am 20 years old. How old is my partner? Let's think step by step."""

response = model.generate_content(prompt)
print(response.text)

# %% [markdown]
# ## Code prompting

# %% [markdown]
# ### Generating code
#
# The Gemini family of models can be used to generate code, configuration and scripts.
#
# Generating code can be helpful when learning to code, learning a new language or for rapidly generating a first draft.
#
# It's important to be aware that since LLMs can't reason, and can repeat training data, it's essential to read and test your code first, and comply with any relevant licenses.

# %%
model = genai.GenerativeModel(
    'gemini-1.5-flash-latest',
    generation_config=genai.GenerationConfig(
        temperature=1,
        top_p=1,
        max_output_tokens=1024,
    ))

# Gemini 1.5 models are very chatty, so it helps to specify they stick to the code.
code_prompt = """
Write a Python function to calculate the factorial of a number. No explanation, provide only the code.
"""

response = model.generate_content(code_prompt)
print(response.text)

# %% [markdown]
# ### Code execution
#
# The Gemini API can automatically run generated code too, and will return the output.

# %%
model = genai.GenerativeModel(
    'gemini-1.5-flash-latest',
    tools='code_execution',)

code_exec_prompt = """
Calculate the sum of the first 14 prime numbers. Only consider the odd primes, and make sure you count them all.
"""

response = model.generate_content(code_exec_prompt)
print(response.text)

# %% [markdown]
# While this looks like a single-part response, you can inspect the response to see the each of the steps: initial text, code generation, execution results, and final text summary.

# %%
for part in response.candidates[0].content.parts:
  print(part)
  print("-----")

# %% [markdown]
# ### Explaining code
#
# The Gemini family of models can explain code to you too.

# %%
file_contents = !curl https://raw.githubusercontent.com/magicmonty/bash-git-prompt/refs/heads/master/gitprompt.sh

explain_prompt = f"""
Please explain what this file does at a very high level. What is it, and why would I use it?

```
{file_contents}
```
"""

model = genai.GenerativeModel('gemini-1.5-flash-latest')

response = model.generate_content(explain_prompt)
print(response.text)
