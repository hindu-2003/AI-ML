# %% [markdown]
# # Generating Text

# %%
# !pip install python-dotenv

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("GOOGLE_API_KEY")

# %%
import google.generativeai as genai

# %%
genai.configure(api_key=api_key)

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
prompt = "What is AI explain advantages and case studies as a beginner"

response = model.generate_content(prompt)

# %%
type(response)
# Out:
# google.generativeai.types.generation_types.GenerateContentResponse

# %%
print(response.text)
# Out:
# Welcome to the exciting world of Artificial Intelligence! For a beginner, let's break it down in simple terms.
#
# ---
#
# ## What is Artificial Intelligence (AI)?
#
# Imagine you're trying to teach a computer to think, learn, and solve problems like a human – or even better! That, in a nutshell, is Artificial Intelligence.
#
# **Here's a simpler way to think about it:**
#
# AI is a field of computer science where we build machines that can perform tasks that typically require human intelligence.
#
# **What kind of "human intelligence" tasks?**
#
# *   **Learning:** Like how you learn from experience, AI can learn from data. (e.g., identifying spam emails after seeing many examples).
# *   **Problem-Solving:** Finding solutions to challenges. (e.g., how to get from point A to point B in traffic).
# *   **Understanding Language:** Being able to read, hear, and make sense of human language. (e.g., talking to Siri or Alexa).
# *   **Recognizing Patterns:** Spotting trends or identifying objects in images. (e.g., facial recognition on your phone).
# *   **Making Decisions:** Based on the information it has learned. (e.g., recommending a movie you might like).
#
# **Is it like robots from movies?**
# Sometimes, but often AI is invisible! It's the "brain" behind many technologies we use daily, not always a physical robot. Many AI systems are software-based.
#
# **A core concept often associated with AI is Machine Learning (ML):**
# Machine Learning is a subset of AI that focuses on enabling systems to *learn from data* without being explicitly programmed for every single task. Instead of telling the computer "if X happens, do Y," you feed it lots of data, and it figures out the rules itself.
#
# ---
#
# ## Advantages of AI
#
# AI isn't just cool tech; it offers significant benefits across many areas of our lives.
#
# 1.  **Automation of Repetitive Tasks:**
#     *   **Advantage:** AI can perform routine, mundane, and high-volume tasks much faster and more consistently than humans. This frees up human workers to focus on more creative, complex, or strategic work.
#     *   **Example:** Data entry, sorting emails, manufacturing line quality checks.
#
# 2.  **Increased Efficiency & Speed:**
#     *   **Advantage:** AI systems can process vast amounts of data and perform computations at speeds impossible for humans, leading to quicker insights and operations.
#     *   **Example:** Financial algorithms can analyze market trends in milliseconds, optimizing trades.
#
# 3.  **Enhanced Accuracy & Reduced Errors:**
#     *   **Advantage:** AI doesn't get tired, distracted, or emotional. It can maintain a high level of accuracy and consistency, reducing human error, especially in critical applications.
#     *   **Example:** AI in medical diagnosis can help identify diseases like cancer from scans with high precision.
#
# 4.  **Handling Dangerous or Difficult Environments:**
#     *   **Advantage:** AI-powered robots and systems can operate in places that are unsafe or inaccessible for humans.
#     *   **Example:** Exploring space, inspecting damaged nuclear plants, bomb disposal, deep-sea exploration.
#
# 5.  **Better Decision-Making & Insights:**
#     *   **Advantage:** By analyzing massive datasets, AI can uncover patterns, correlations, and insights that humans might miss, leading to more informed and data-driven decisions.
#     *   **Example:** Predicting consumer behavior for marketing, identifying fraud in banking, forecasting weather patterns.
#
# 6.  **Personalization & Customization:**
#     *   **Advantage:** AI can tailor experiences, recommendations, and content to individual users based on their preferences and past behavior.
#     *   **Example:** Streaming services suggesting movies, e-commerce sites recommending products, personalized learning platforms.
#
# 7.  **Accessibility for People with Disabilities:**
#     *   **Advantage:** AI can create tools that make technology and information more accessible.
#     *   **Example:** Speech-to-text and text-to-speech tools, AI-powered navigation for visually impaired individuals, sign language translation apps.
#
# ---
#
# ## Case Studies (Real-World Examples)
#
# Let's look at how AI is being used today:
#
# 1.  **Customer Service Chatbots and Virtual Assistants:**
#     *   **How AI is used:** AI-powered chatbots (like those on many company websites) and virtual assistants (like Siri, Alexa, Google Assistant) use Natural Language Processing (NLP) to understand human language, answer questions, provide information, and even perform tasks.
#     *   **Advantage:** Provides instant support 24/7, reduces call center wait times, and handles common queries efficiently.
#
# 2.  **Personalized Recommendations (E-commerce & Streaming):**
#     *   **How AI is used:** Companies like Amazon, Netflix, and Spotify use AI algorithms to analyze your past purchases, viewing history, ratings, and even what similar users like. They then use this data to recommend products, movies, or music you're likely to enjoy.
#     *   **Advantage:** Enhances user experience, increases engagement, and boosts sales/subscriptions by showing relevant content.
#
# 3.  **Self-Driving Cars:**
#     *   **How AI is used:** Autonomous vehicles (like those from Tesla, Waymo) use a combination of AI, machine learning, computer vision, and sensors (cameras, radar, lidar) to perceive their surroundings, understand traffic rules, predict the behavior of other vehicles and pedestrians, and make driving decisions in real-time.
#     *   **Advantage:** Promises increased road safety by reducing human error, potentially more efficient traffic flow, and greater accessibility for those unable to drive.
#
# 4.  **Fraud Detection in Finance:**
#     *   **How AI is used:** Banks and financial institutions employ AI to monitor millions of transactions in real-time. The AI learns what "normal" transaction patterns look like for a customer. When it detects an unusual or suspicious activity (e.g., a large purchase in a foreign country you've never visited), it flags it as potential fraud.
#     *   **Advantage:** Protects customers and banks from financial loss, identifies and prevents fraudulent activities much faster than human analysts could.
#
# 5.  **Medical Diagnosis and Drug Discovery:**
#     *   **How AI is used:** AI can analyze medical images (X-rays, MRIs) to spot anomalies (like tumors) with high accuracy, sometimes even before human doctors. In drug discovery, AI can simulate how different compounds interact, drastically speeding up the process of finding new medications.
#     *   **Advantage:** Aids doctors in faster and more accurate diagnoses, accelerates the development of life-saving drugs, and can even suggest personalized treatment plans.
#
# ---
#
# AI is a transformative technology that is constantly evolving. While there are ethical considerations and challenges, its ability to augment human capabilities and solve complex problems makes it one of the most exciting fields of our time!
