# %% [markdown]
# # Generation Configuration (Text Generation Parameters)
#
# We can pass in configuration values to further refine the type of output you will get.

# %%
api_key = 'AIzaSyDNHhGZH210RYE4gRR-09PtwKcxCSNqi1E'

# %%
import google.generativeai as genai
genai.configure(api_key=api_key)

# %%
model = genai.GenerativeModel('models/gemini-1.5-flash')

# %% [markdown]
# ## The Generation Configuration Object
#
# We can easily supply arguments to a geneartion configuration object:

# %%
config = genai.types.GenerationConfig(temperature=1.0,max_output_tokens=2000,candidate_count=1)

# %%
def get_response(prompt, generation_config={}):
    response = model.generate_content(contents=prompt,generation_config=generation_config)
    return response

# %%
result = get_response("Tell me about Myself Dr N V Ganapathi Raju VCube Software Solutions Hyderabad")
print(result.text)
# Out:
# I do not have access to private information about individuals, including Dr. N V Ganapathi Raju.  Therefore, I cannot tell you about him.  To learn about him, you could try searching online (e.g., LinkedIn, Google) using his full name and affiliation with VCube Software Solutions in Hyderabad.  You might also find information on VCube Software Solutions' website.

# %%
result = get_response("Tell me about Myself Dr N V Ganapathi Raju Professor IT department GRIET Hyderabad", generation_config= config)

# %%
result.text
# Out:
# 'I do not have access to private information about individuals, including Dr. N. V. Ganapathi Raju.  My knowledge is based on publicly available information.  To learn about Dr. Raju, I suggest you try the following:\n\n* **Search online:** Use search engines like Google, Bing, or DuckDuckGo to search for "Dr. N. V. Ganapathi Raju GRIET Hyderabad."  This might lead you to his profile on the GRIET website, research publications, or other online resources.\n* **Check the GRIET website:** The official website of GRIET (Gokaraju Rangaraju Institute of Engineering and Technology) in Hyderabad should have a faculty directory listing professors in the IT department.\n* **Look for publications:**  Search academic databases like Google Scholar or Scopus for publications by an author with that name and affiliation.\n\nThis will help you find information about his research interests, education, and experience.\n'

# %%
result.candidates[0].content.parts[0].text
# Out:
# 'I do not have access to private information about individuals, including Dr. N. V. Ganapathi Raju.  My knowledge is based on publicly available information.  To learn about Dr. Raju, I suggest you try the following:\n\n* **Search online:** Use search engines like Google, Bing, or DuckDuckGo to search for "Dr. N. V. Ganapathi Raju GRIET Hyderabad."  This might lead you to his profile on the GRIET website, research publications, or other online resources.\n* **Check the GRIET website:** The official website of GRIET (Gokaraju Rangaraju Institute of Engineering and Technology) in Hyderabad should have a faculty directory listing professors in the IT department.\n* **Look for publications:**  Search academic databases like Google Scholar or Scopus for publications by an author with that name and affiliation.\n\nThis will help you find information about his research interests, education, and experience.\n'

# %% [markdown]
# ## Gemini LLM Configuration Parameters
#
# ### Temperature
# In Gemini LLM, the `temperature` parameter plays a crucial role in the response generation process. It's instrumental during the sampling phase, particularly when `top_p` and `top_k` parameters are in effect.
#
# Essentially, `temperature` influences the randomness in token selection:
#
# - **Low temperatures** are optimal for prompts necessitating deterministic, concise, and less creative responses.
# - **High temperatures** foster diverse and creative outcomes, enhancing the model's response variability.
#
#     - **Range**: `0.0 - 1.0`
#     - **Default Settings**:
#         - **gemini-pro**: `0.9`
#         - **gemini-pro-vision**: `0.4`

# %%
config = genai.types.GenerationConfig(temperature=0.0)
result = get_response("Tell me about the Hyderabad India",generation_config=config)
print(result.text)
# Out:
# Hyderabad, located in the southern Indian state of Telangana, is a vibrant city steeped in history and brimming with modern energy.  It's often called the "City of Pearls" due to its long-standing history of pearl trading and craftsmanship.  Here's a glimpse into what makes Hyderabad unique:
#
# **History and Culture:**
#
# * **Nizams:** Hyderabad's rich history is intrinsically linked to the Asaf Jahi dynasty, the Nizams, who ruled the princely state of Hyderabad for over two centuries. Their legacy is visible in the city's magnificent architecture, cuisine, and cultural traditions.
# * **Charminar:** This iconic monument, built in 1591, is the symbol of Hyderabad.  It's a stunning example of Indo-Islamic architecture and sits at the heart of the old city.
# * **Golconda Fort:** A majestic fort perched on a hill, Golconda boasts a fascinating history, impressive acoustics, and stunning views of the city.  It was once a significant diamond trading center.
# * **Qutb Shahi Tombs:**  These elegant tombs, showcasing the architectural brilliance of the Qutb Shahi dynasty, are a testament to the region's rich past.
# * **Chowmahalla Palace:** The former residence of the Nizams, this sprawling palace complex offers a glimpse into the opulent lifestyle of the rulers.
#
# **Modern Hyderabad:**
#
# * **IT Hub:** Hyderabad is a major IT hub, home to numerous multinational companies and a thriving tech industry. This has led to significant economic growth and modernization.
# * **Pharmaceutical Industry:**  The city also has a strong presence in the pharmaceutical sector, with many major pharmaceutical companies having facilities here.
# * **Education:**  Hyderabad boasts several prestigious universities and educational institutions, attracting students from across India and the world.
# * **Cuisine:** Hyderabadi cuisine is renowned for its rich and flavorful dishes, particularly the famous Biryani, Haleem, and Mirchi ka Salan.  The city offers a diverse culinary scene, blending traditional flavors with modern influences.
# * **Shopping:** From traditional markets selling pearls and handicrafts to modern malls, Hyderabad offers a wide range of shopping experiences.
# * **People:** The people of Hyderabad are known for their warm hospitality and welcoming nature.  The city is a melting pot of cultures and languages, reflecting its diverse history.
#
#
# **Things to consider when visiting:**
#
# * **Traffic:** Hyderabad can experience heavy traffic congestion, especially during peak hours.
# * **Climate:** The city has a hot and humid climate for much of the year.
# * **Language:** While Telugu is the official language, Urdu and Hindi are also widely spoken. English is commonly understood in most tourist areas.
#
#
# In short, Hyderabad is a city that seamlessly blends its rich historical heritage with its modern dynamism, offering a unique and unforgettable experience for visitors.  It's a place where ancient monuments stand alongside bustling IT parks, and where traditional flavors mingle with contemporary trends.

# %%
config = genai.types.GenerationConfig(temperature=1.0)
result = get_response("Tell me about the Hyderabad India",generation_config=config)
print(result.text)
# Out:
# Hyderabad, located in the Indian state of Telangana, is a vibrant city with a rich history and diverse culture.  Here's a glimpse into what makes it special:
#
# **History & Culture:**
#
# * **Ancient Roots:**  Founded in 1591 by Muhammad Quli Qutb Shah, the city boasts a long and fascinating history, blending Persian, Mughal, and Indian influences.  It was once the capital of the Qutb Shahi dynasty and later the princely state of Hyderabad.
# * **Architectural Marvels:** Hyderabad is renowned for its stunning architecture.  The Charminar, a majestic monument, is its iconic symbol.  Other notable landmarks include the Golconda Fort, a formidable historical fortress, and the Chowmahalla Palace, a sprawling palace showcasing the grandeur of the Nizams.  The Salar Jung Museum houses an impressive collection of artifacts from around the world.  Numerous mosques, temples, and churches reflect the city's religious diversity.
# * **Nizam's Legacy:** The Nizams, the rulers of Hyderabad State, left an indelible mark on the city's culture and architecture. Their opulent lifestyle is reflected in the city's grandeur and its diverse population.
# * **Language & People:** Telugu is the primary language, though Urdu and Hindi are also widely spoken.  The city's population is a melting pot of different communities, creating a unique cultural blend.
#
# **Modern Hyderabad:**
#
# * **IT Hub:**  Hyderabad has emerged as a major center for information technology, attracting numerous multinational companies and contributing significantly to its economic growth.  It's often called the "Cyberabad" due to its IT sector.
# * **Education & Research:** The city is home to several prestigious universities, research institutions, and educational centers, making it a hub for learning and innovation.
# * **Cuisine:** Hyderabadi cuisine is renowned for its richness and flavors.  The famous Biryani, a mixed rice dish, is a must-try, along with other local delicacies like Haleem and Mirchi ka Salan.
# * **Shopping:** From traditional markets brimming with textiles and jewelry to modern malls, Hyderabad offers a wide array of shopping experiences. Laad Bazaar, known for its bangles, is a popular attraction.
# * **Tourism:** Hyderabad is a popular tourist destination, attracting visitors from both India and abroad.  Its historical sites, vibrant culture, and delicious food make it a compelling place to explore.
#
# **Challenges:**
#
# Like many rapidly growing cities, Hyderabad faces challenges including traffic congestion, pollution, and infrastructure development. However, the city continues to strive for progress and sustainable growth.
#
#
# In short, Hyderabad is a captivating city offering a unique blend of history, culture, and modernity.  Its rich heritage, vibrant atmosphere, and growing economy make it a fascinating place to visit or live.

# %% [markdown]
# ### max_output_tokens
# The `max_output_tokens` parameter defines the upper limit of tokens generated in a response. Notably, a token approximates four characters, translating to about 60-80 words for 100 tokens. Adjust this parameter based on the desired response length:
#
# - **Lower values** lead to shorter responses.
# - **Higher values** enable more extensive responses.
#
#     - **Ranges**:
#         - **gemini-pro**: `1-8192` (default: `8192`)
#         - **gemini-pro-vision**: `1-2048` (default: `2048`)

# %%
config = genai.types.GenerationConfig(max_output_tokens=500)
result = get_response("Tell me about the Hyderabad India",generation_config=config)
print(result.text)
# Out:
# Hyderabad, located in the southern Indian state of Telangana, is a vibrant and historic city known for its rich culture, diverse cuisine, and impressive architectural landmarks.  Here's a glimpse into what makes Hyderabad special:
#
# **History & Culture:**
#
# * **The Nizams:** Hyderabad's history is deeply intertwined with the Asaf Jahi dynasty, also known as the Nizams, who ruled the princely state of Hyderabad for over two centuries.  Their legacy is visible in the city's architecture, traditions, and even its cuisine.  They fostered a unique blend of Persian, Mughal, and local Deccan cultures.
# * **A Cosmopolitan City:**  Over the centuries, Hyderabad has absorbed influences from various cultures, creating a truly cosmopolitan atmosphere. This is reflected in its diverse population, languages spoken (Urdu, Telugu, Hindi, and English being prominent), and the fusion of traditions.
# * **Festivals:** Hyderabad celebrates a multitude of festivals, both religious and secular, with great enthusiasm.  These include major Hindu, Muslim, and Christian festivals, each marked by unique traditions and celebrations.
#
# **Architecture & Landmarks:**
#
# * **Charminar:** This iconic monument, built in 1591, is the symbol of Hyderabad.  It's a stunning example of Indo-Islamic architecture and is situated in the heart of the old city.
# * **Golconda Fort:**  A magnificent historical fort overlooking the city, Golconda is renowned for its acoustics and intricate architecture.  It was once a powerful kingdom and a center of the diamond trade.
# * **Chowmahalla Palace:**  The former residence of the Nizams, this palace showcases a blend of architectural styles and opulent interiors.  It offers a glimpse into the grandeur of the Nizam's rule.
# * **Qutb Shahi Tombs:**  These impressive tombs are located near Golconda Fort and are a testament to the architectural prowess of the Qutb Shahi dynasty.
# * **Mecca Masjid:**  One of the oldest and largest mosques in India, the Mecca Masjid is a significant religious site.
#
# **Cuisine:**
#
# * **Biryani:** Hyderabad is famous worldwide for its delectable biryani, a mixed rice dish with meat and spices.  The Hyderabadi biryani is particularly renowned for its unique flavors and aromatic spices.
# * **Haleem:** A hearty and flavorful stew, typically eaten during Ramadan, is another culinary specialty of Hyderabad.
# * **

# %% [markdown]
# ### top_k
# `top_k` parameter influences the model's token selection strategy for generating outputs. It's a measure of how many of the most probable tokens are considered at each step:
#
# - A **top_k of 1** implies a deterministic approach, choosing the most probable token.
# - Higher **top_k values** introduce diversity, selecting from a broader range of probable tokens based on the set `temperature`.
#
#     - **Range**: `1-40`
#     - **Default Settings**:
#         - **gemini-pro-vision**: `32`
#         - **gemini-pro**: Not specified (none)

# %%
config = genai.types.GenerationConfig(top_k=1)
result = get_response("Tell me about the Hyderabad India",generation_config=config)
print(result.text)
# Out:
# Hyderabad, located in the southern Indian state of Telangana, is a vibrant city with a rich history and a unique blend of cultures.  Here's a glimpse into what makes it special:
#
# **History and Culture:**
#
# * **Charminar:** This iconic monument, built in 1591, is the symbol of Hyderabad.  It's a stunning example of Indo-Islamic architecture and a bustling marketplace surrounds it.
# * **Golconda Fort:** A majestic fort perched on a hill, Golconda boasts impressive architecture, intricate carvings, and a fascinating history.  It was once a powerful kingdom and renowned for its diamonds.
# * **Qutb Shahi Tombs:** These elegant tombs are a testament to the architectural prowess of the Qutb Shahi dynasty, who ruled Hyderabad for nearly two centuries.
# * **Chowmahalla Palace:**  The former residence of the Nizams (the rulers of the princely state of Hyderabad), this palace showcases a blend of Indo-European architectural styles and houses a museum displaying royal artifacts.
# * **Salar Jung Museum:**  One of India's largest museums, it houses an eclectic collection of art and artifacts from around the world, reflecting the diverse tastes of its founder.
# * **Ramoji Film City:**  One of the world's largest integrated film studios, it's a popular tourist destination offering a glimpse into the world of filmmaking.
#
# **Cuisine:**
#
# Hyderabad is renowned for its delectable cuisine, a unique fusion of Mughlai, Deccani, and local flavors.  Some must-try dishes include:
#
# * **Biryani:**  Hyderabad's biryani is legendary, characterized by its layered preparation and fragrant spices.  It's a culinary masterpiece.
# * **Haleem:** A hearty and flavorful stew, typically made with meat, lentils, and wheat.  It's a popular dish during Ramadan.
# * **Irani Chai:**  A strong and sweet tea served in small glasses, often enjoyed with Osmania biscuits.
# * **Paya:** A flavorful soup made from trotters.
#
# **People and Language:**
#
# Hyderabad's population is diverse, with a mix of Telugu, Urdu, Hindi, and English speakers.  The city has a vibrant and cosmopolitan atmosphere, welcoming people from all walks of life.
#
# **Modern Hyderabad:**
#
# Beyond its historical attractions, Hyderabad is a rapidly developing metropolis.  It's a major center for information technology, pharmaceuticals, and biotechnology, attracting talent from across the country and the world.  The city boasts modern infrastructure, including a well-developed public transportation system.
#
# **In short:** Hyderabad offers a unique and unforgettable experience, blending its rich historical heritage with its modern dynamism. It's a city that captivates visitors with its stunning architecture, delicious cuisine, and warm hospitality.

# %%
config = genai.types.GenerationConfig(top_k=40)
result = get_response("Tell me about the Hyderabad India",generation_config=config)
print(result.text)
# Out:
# Hyderabad, located in the southern Indian state of Telangana, is a vibrant city steeped in history and culture, often referred to as the "City of Pearls."  Its rich heritage is evident in its architecture, cuisine, and the blend of different cultures that have shaped it over centuries. Here's a glimpse of what makes Hyderabad special:
#
# **History & Culture:**
#
# * **Nizam's Legacy:**  Hyderabad flourished under the rule of the Nizams, a dynasty of Asaf Jahi rulers. Their influence is visible in the magnificent palaces, mosques, and forts that dot the city landscape. The Charminar, a stunning monument, stands as a symbol of Hyderabad.
# * **Fusion of Cultures:**  A unique blend of Persian, Mughal, and local Telugu cultures created a distinct Hyderabadi identity.  This is reflected in its architecture, language (Deccani Urdu), cuisine, and traditions.
# * **Historical Sites:**  Beyond the Charminar, other significant sites include Golconda Fort (a massive fort with a rich history), Chowmahalla Palace (the former residence of the Nizams), Qutb Shahi Tombs (elaborate tombs of the Qutb Shahi dynasty), and Salar Jung Museum (a museum housing a vast collection of art and artifacts).
#
# **Modern Hyderabad:**
#
# * **IT Hub:**  Hyderabad has emerged as a major Information Technology hub, attracting numerous multinational companies and contributing significantly to its economic growth.  It's often compared to Bengaluru (Bangalore) in this aspect.
# * **Education:**  The city boasts several prestigious universities and educational institutions, making it a center of learning.
# * **Cuisine:**  Hyderabadi cuisine is world-renowned, particularly for its biryanis (especially the famous Hyderabadi biryani), haleem (a hearty stew), and other rich and flavorful dishes.
# * **Shopping:**  Laad Bazaar, a bustling market, is famous for its bangles and traditional jewelry.  The city also offers a wide range of modern shopping malls and boutiques.
# * **Modern Infrastructure:**  While retaining its historical charm, Hyderabad also features modern infrastructure, including well-developed roads, transportation systems, and public spaces.
#
# **Things to consider when visiting:**
#
# * **Language:**  While Hindi and English are widely spoken, Telugu is the official language of Telangana.  Knowing a few basic Telugu phrases can enhance your experience.
# * **Climate:**  Hyderabad has a hot and humid climate, particularly during the summer months.
# * **Transportation:**  Auto-rickshaws, taxis, and buses are readily available for local transportation.
#
#
# In short, Hyderabad is a fascinating city that successfully balances its rich historical past with its modern dynamism. It offers a unique cultural experience, delicious food, and plenty of opportunities for exploration.

# %% [markdown]
# ### top_p
# The `top_p` parameter, akin to `top_k`, modifies the token selection process. It considers tokens from the most to least probable, cumulatively, until their probabilities match the `top_p` value. The model then selects the next token within this subset, guided by the `temperature` parameter:
#
# - **Lower `top_p` values** lead to more predictable responses.
# - **Higher `top_p` values** permit a wider array of potential responses, injecting randomness.
#
#     - **Range**: `0.0 - 1.0`
#     - **Default**: `1.0`

# %%
config = genai.types.GenerationConfig(top_p=0)
result = get_response("Tell me about the Hyderabad India",generation_config=config)
print(result.text)
# Out:
# Hyderabad, located in the southern Indian state of Telangana, is a vibrant city steeped in history and brimming with modern energy.  It's often called the "City of Pearls" due to its long history of pearl trading, and its rich cultural heritage is a captivating blend of Persian, Mughal, and Indian influences.
#
# Here's a glimpse into what makes Hyderabad special:
#
# **History and Culture:**
#
# * **Mughal and Qutb Shahi Legacy:**  The city's architecture reflects its rich past, with magnificent structures like the Charminar, Golconda Fort, and Chowmahalla Palace showcasing the grandeur of the Qutb Shahi and Mughal empires. These landmarks are not just beautiful; they tell stories of power, trade, and cultural exchange.
# * **Deccani Cuisine:** Hyderabad is renowned for its unique and delicious cuisine, known as Deccani cuisine.  It's a flavorful blend of Mughlai and local flavors, featuring dishes like Biryani (a mixed rice dish with meat and spices), Haleem (a hearty stew), and Mirchi ka Salan (a spicy chili gravy).  Food is a significant part of the city's identity.
# * **Festivals and Traditions:** Hyderabad celebrates numerous festivals with great enthusiasm, showcasing its diverse cultural tapestry.  From the grandeur of Ramzan to the vibrant colors of Diwali, the city comes alive with festivities.
# * **Language and People:**  The primary language spoken is Telugu, but Urdu is also widely used and understood, reflecting the city's historical influences.  The people of Hyderabad are known for their warm hospitality and welcoming nature.
#
# **Modern Hyderabad:**
#
# * **IT Hub:**  Hyderabad has emerged as a major Information Technology (IT) hub in India, attracting numerous multinational companies and contributing significantly to the city's economic growth.  This has led to a modern, cosmopolitan atmosphere.
# * **Education and Research:**  The city boasts several prestigious educational institutions, including universities and research centers, making it a center for learning and innovation.
# * **Tourism and Entertainment:**  Hyderabad is a popular tourist destination, attracting visitors from across the globe.  Beyond historical sites, it offers modern entertainment options, shopping malls, and a thriving nightlife.
# * **Infrastructure:**  While still developing, Hyderabad's infrastructure is improving, with better roads, transportation systems, and public services.
#
# **Things to do in Hyderabad:**
#
# * **Visit the Charminar:**  This iconic monument is a must-see, representing the heart of the old city.
# * **Explore Golconda Fort:**  Discover the history and architecture of this magnificent fort, known for its acoustics and stunning views.
# * **Wander through Chowmahalla Palace:**  Experience the opulence of the Nizams' former residence.
# * **Indulge in the local cuisine:**  Sample the delicious Biryani, Haleem, and other culinary delights.
# * **Shop for pearls and handicrafts:**  Hyderabad is famous for its pearls and traditional handicrafts.
#
#
# In short, Hyderabad is a city that seamlessly blends its rich historical heritage with its modern dynamism, offering a unique and unforgettable experience for visitors.  It's a place where ancient stories meet contemporary progress, creating a captivating and vibrant urban landscape.

# %%
config = genai.types.GenerationConfig(top_p=1)
result = get_response("Tell me about the Hyderabad India",generation_config=config)
print(result.text)
# Out:
# Hyderabad, the capital of Telangana and previously a joint capital with Andhra Pradesh, is a vibrant and historic city in southern India.  It's renowned for its rich culture, delectable cuisine, impressive architecture, and a blend of traditional and modern influences. Here's a glimpse into what makes Hyderabad special:
#
# **History and Culture:**
#
# * **Nizams' Legacy:** Hyderabad's character is significantly shaped by its history as the capital of the princely state of Hyderabad under the Asaf Jahi dynasty (Nizams). Their reign left behind a legacy of grand palaces, mosques, and forts, reflecting a unique blend of Persian, Mughal, and local Deccan architectural styles.
# * **Charminar:** This iconic monument, built in 1591, is a symbol of the city and its architecture. It's located at the heart of the old city and surrounded by bustling markets.
# * **Golconda Fort:** A formidable fort situated on a hilltop, Golconda boasts impressive acoustics and a fascinating history.  It was once a significant diamond trading center.
# * **Qutb Shahi Tombs:**  These elegant tombs showcase the architectural brilliance of the Qutb Shahi dynasty, predecessors to the Nizams.
# * **Diverse Culture:**  Hyderabad is a melting pot of cultures, with a significant population of Hindus, Muslims, and other communities living together harmoniously. This diversity is reflected in its festivals, traditions, and cuisine.
#
# **Cuisine:**
#
# * **Biryani:** Hyderabad is famous worldwide for its delicious biryani, a mixed rice dish with meat, vegetables, and aromatic spices. Several variations exist, each with its unique flavour profile.
# * **Haleem:** A hearty and rich stew, usually made with meat and lentils, is a popular delicacy, especially during Ramadan.
# * **Mirchi Bajji:** Spicy green chillies dipped in batter and deep-fried.
# * **Osmania Biscuits:** These crispy biscuits are a beloved snack.
# * **Irani Chai:**  A strong, sweet tea served in small glasses, a staple of Hyderabad's rich café culture.
#
# **Economy and Modernity:**
#
# * **IT Hub:** Hyderabad has emerged as a major IT hub in India, attracting numerous multinational companies and contributing significantly to the state's economy.
# * **Pharmaceutical Industry:**  A large pharmaceutical industry is also based in Hyderabad.
# * **Education:**  Several prestigious educational institutions, including universities and colleges, are located in the city.
# * **Modern Infrastructure:**  Hyderabad is developing rapidly with modern infrastructure, including multiplexes, shopping malls, and improved transportation systems.
#
#
# **Challenges:**
#
# Like many rapidly growing cities, Hyderabad faces challenges such as traffic congestion, pollution, and infrastructure limitations.  However, ongoing development efforts aim to address these issues.
#
#
# In short, Hyderabad is a city that offers a fascinating mix of history, culture, delicious food, and modern advancements, making it a unique and memorable destination.

# %% [markdown]
# ### candidate_count
# The `candidate_count` parameter determines the quantity of different response variations the model generates. For Gemini LLM, this value is fixed:
#
# - **Required Value**: `1`

# %%
config = genai.types.GenerationConfig(candidate_count=1)
result = get_response("Give me 3 top facts about India",generation_config=config)

# %%
print(result.text)
# Out:
# 1. **Incredible Linguistic Diversity:** India is home to over 122 major languages and thousands of dialects.  This makes it one of the most linguistically diverse countries in the world, reflecting its rich and complex history.
#
# 2. **Ancient Civilization & History:**  India boasts a continuous civilization tracing back thousands of years, with evidence of urban settlements dating back to the Indus Valley Civilization (c. 3300-1300 BCE).  It's a cradle of major religions like Hinduism, Buddhism, Jainism, and Sikhism.
#
# 3. **Massive & Young Population:** India has the world's largest population and a significantly young demographic profile. This presents both immense challenges (resource management, infrastructure) and opportunities (economic growth, innovation) for the country.

# %% [markdown]
# ### stop_sequences
# `stop_sequences` is a feature allowing the specification of strings that prompt the model to cease text generation.
#
# The response is truncated at the first occurrence of any listed string. This feature is sensitive to the case of the strings:
#
# - **Usage Example**: If "Str" and "reverse" are in `stop_sequences`, the model stops generating text at their first appearance.
# - **Limitation**: A maximum of 5 strings can be listed in `stop_sequences`.

# %%
config = genai.types.GenerationConfig(stop_sequences=['x','X'])
result = get_response("Give me a list of all Job Roles of Python",generation_config=config)
print(result.text)
# Out:
# It's impossible to give an e

# %%
config = genai.types.GenerationConfig(stop_sequences=[])
result = get_response("Write about which top companies using Python'",generation_config=config)
print(result.text)
# Out:
# Python's versatility and extensive libraries have made it a favorite among many top companies across diverse sectors.  It's impossible to create an exhaustive list, but here are some prominent examples categorized by industry:
#
# **Technology Giants:**
#
# * **Google:**  Python is one of Google's official server-side languages and is used extensively in various projects, including search algorithms, data analysis, and machine learning.  Many internal tools and infrastructure are built using Python.
# * **Facebook (Meta):**  Uses Python for its infrastructure management, data analysis, machine learning, and even some parts of its web development.
# * **Instagram:**  Heavily reliant on Python for its backend infrastructure and data processing.  A significant portion of its platform was initially built using Python's Django framework.
# * **Dropbox:**  A large portion of Dropbox's core infrastructure is written in Python.
# * **Spotify:**  Uses Python for backend services, data analysis, and machine learning tasks.
# * **Netflix:**  Employs Python for various tasks, including data science, machine learning, and security.
# * **Reddit:**  Its website and many internal tools are built with Python.
# * **Uber:**  Uses Python extensively for its machine learning algorithms, data analysis, and microservices architecture.
#
# **Other Notable Companies:**
#
# * **NASA:**  Uses Python for various data analysis and scientific computing tasks.
# * **JP Morgan Chase:**  Utilizes Python for quantitative analysis, algorithmic trading, and risk management.
# * **IBM:**  Leverages Python in its AI and machine learning initiatives, as well as for data science projects.
# * **Amazon:**  While not primarily a Python-based company, it uses Python significantly for various data science, machine learning, and AWS services.
# * **Microsoft:**  Increasingly uses Python for its cloud services (Azure) and AI/ML projects.
#
#
# **Why these companies choose Python:**
#
# The reasons for Python's popularity amongst these companies are manifold:
#
# * **Large and Active Community:**  A vast community provides ample support, readily available libraries, and continuous development.
# * **Extensive Libraries:**  Libraries like NumPy, Pandas, Scikit-learn, and TensorFlow cater to diverse needs, especially in data science, machine learning, and scientific computing.
# * **Ease of Use and Readability:** Python's clear syntax and relatively simple learning curve allow for faster development and easier maintenance.
# * **Versatility:**  Applicable across diverse domains, from web development to data science to scripting.
# * **Open-Source and Free:**  Reduces development costs and promotes collaboration.
#
#
# It's important to remember that many companies use a mix of programming languages, and Python often plays a crucial role alongside others like Java, C++, or Go depending on specific needs.  This list showcases a selection of companies where Python has a significant and visible presence.

# %%
config = genai.types.GenerationConfig(stop_sequences=['Sincerely'])
result = get_response("Write a about Salary Packages for Python Programmer . End it with 'Sincerely'",generation_config=config)
print(result.text)
# Out:
# Salary packages for Python programmers vary significantly based on several factors, including experience level, location, company size, and specific skills.  Entry-level positions might offer salaries ranging from $60,000 to $80,000 annually in many parts of the United States, while experienced senior Python developers can command salaries well over $150,000, and even higher in major tech hubs like San Francisco or New York City.
#
# Beyond base salary, compensation packages often include additional benefits. These benefits can be substantial and contribute significantly to overall compensation.  Common benefits include health insurance (medical, dental, and vision), paid time off (vacation, sick leave), retirement plans (401k matching or similar), life insurance, disability insurance, and stock options or bonuses, particularly in larger companies.  The availability and generosity of these benefits vary widely depending on the employer and the candidate's negotiation skills.
#
# Specialized skills, such as expertise in machine learning, data science, or specific Python frameworks (like Django or Flask), can significantly impact earning potential.  Similarly, holding relevant certifications can enhance a candidate's value and increase their negotiating power.  The demand for skilled Python developers is consistently high across numerous industries, from software development and web development to data science and finance, leading to competitive salary offers in many cases.  Researching specific job postings and salary data websites for your target location and experience level will offer the most accurate and up-to-date information.
