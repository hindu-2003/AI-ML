# %%
import sqlite3
connection=sqlite3.connect("stud.db")

cursor=connection.cursor()

table_info="""
Create table STUDENT(NAME VARCHAR(25),CLASS VARCHAR(25),SECTION VARCHAR(25),MARKS INT);

"""
cursor.execute(table_info)

# %%
cursor.execute('''Insert Into STUDENT values('Stud 1','Data Science','A',100)''')
cursor.execute('''Insert Into STUDENT values('Stud 2','ML','B',98)''')
cursor.execute('''Insert Into STUDENT values('Stud 3','Gen AI','A',100)''')
cursor.execute('''Insert Into STUDENT values('Stud 4','Python','B',90)''')

# %%
cursor.execute('''Insert Into STUDENT values('Stud 5','Azure Python','C',80)''')

print("The isnerted records are")
data=cursor.execute('''Select * from STUDENT''')

for row in data:
    print(row)

connection.commit()
connection.close()
# Out:
# The isnerted records are
# ('Stud 1', 'Data Science', 'A', 100)
# ('Stud 2', 'ML', 'B', 98)
# ('Stud 3', 'Gen AI', 'A', 100)
# ('Stud 4', 'Python', 'B', 90)
# ('Stud 5', 'Azure Python', 'C', 80)

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('stud.db')

df = pd.read_sql_query("Select * from STUDENT", conn)
df
# Out:
#      NAME         CLASS SECTION  MARKS
# 0  Stud 1  Data Science       A    100
# 1  Stud 2            ML       B     98
# 2  Stud 3        Gen AI       A    100
# 3  Stud 4        Python       B     90
# 4  Stud 5  Azure Python       C     80

# %%
data_string = df.head().to_string(index=False)

# %%
data_string
# Out:
# '  NAME        CLASS SECTION  MARKS\nStud 1 Data Science       A    100\nStud 2           ML       B     98\nStud 3       Gen AI       A    100\nStud 4       Python       B     90\nStud 5 Azure Python       C     80'

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyApew7uucQDLPWNhC2xHeuWJtF2h8vr1_0")

prompt = f"""
You are a data analyst.

Here is a snapshot of the SQLite table:
{data_string}

Please analyze and give me a summary of key insights in 3 bullet formats.
"""

response = genai.GenerativeModel("gemini-2.5-flash").generate_content(prompt)
print(response.text)
