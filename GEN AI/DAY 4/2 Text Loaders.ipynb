# %% [markdown]
# ### DATA Loaders

# %% [markdown]
# https://python.langchain.com/docs/integrations/document_loaders/

# %%
# !pip install langchain

# %%
# ! pip install langchain-core

# %% [markdown]
# * langchain-core provides base classes and primitives for:
#
#     * Prompts
#
#     * LLM interfaces
#
#     * Output parsers
#
#     * Runnables (chains)
#
#     * Messages (for chat models)
#
#     * Callbacks
#
#     * Tools interface
#
#     * Memory interface

# %%
# ! pip install langchain-community

# %% [markdown]
# * langchain-community is the package that contains third-party integrations for LangChain Core.
#
# It provides:
#
#     📄 Document loaders (PDF, CSV, DOCX, HTML, Notion, Web pages, etc.)
#
#     🧠 Vector databases (FAISS, Chroma, Weaviate, Pinecone, Milvus)
#
#     🔍 Retrievers
#
#     🛠 Tools (Search APIs, calculators, web scrapers)
#
#     🔌 Embeddings integrations (HuggingFace, Ollama, OpenAI, Cohere, etc.)

# %% [markdown]
# | Package                    | Purpose                                                  |
# | -------------------------- | -------------------------------------------------------- |
# | `langchain-core`           | Base abstractions (prompts, chains, runnables, messages) |
# | `langchain-community`      | Loaders, vector DBs, tools                               |
# | `langchain-openai`         | OpenAI models                                            |
# | `langchain-ollama`         | Ollama models                                            |
# | `langchain-text-splitters` | Chunking logic                                           |

# %% [markdown]
# ### TextLoader

# %% [markdown]
# * TextLoader is used to load text files (.txt) into LangChain document format.
#
# * LangChain stores documents as Document objects.
#
# * Each document contains:
#
#     * page_content → actual text
#
#     * metadata → file information

# %%
from langchain_community.document_loaders.text import TextLoader
# Out:
# WARNING:tensorflow:From C:\Users\nvgra\anaconda3\annacond\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
loader=TextLoader('speech.txt')

loader

# %% [markdown]
#  * At this stage file is not loaded yet.

# %%
text_documents=loader.load()

text_documents
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='The world must be made safe for democracy. Its peace must be planted upon the tested foundations of political liberty. We have no selfish ends to serve. We desire no conquest, no dominion. We seek no indemnities for ourselves, no material compensation for the sacrifices we shall freely make. We are but one of the champions of the rights of mankind. We shall be satisfied when those rights have been made as secure as the faith and the freedom of nations can make them.\n\nJust because we fight without rancor and without selfish object, seeking nothing for ourselves but what we shall wish to share with all free peoples, we shall, I feel confident, conduct our operations as belligerents without passion and ourselves observe with proud punctilio the principles of right and of fair play we profess to be fighting for.\n\nâ€¦\n\nIt will be all the easier for us to conduct ourselves as belligerents in a high spirit of right and fairnes
# ...

# %% [markdown]
# * Now LangChain:
#
#    * Opens the file
#
#    * Reads text
#
#    * Converts it into Document objects
#
#    * load() returns a list of documents.

# %% [markdown]
# | Field          | Meaning          |
# | -------------- | ---------------- |
# | `page_content` | actual text      |
# | `metadata`     | file information |

# %%
text = text_documents[0].page_content

print(text)  # show first 500 characters
# Out:
# The world must be made safe for democracy. Its peace must be planted upon the tested foundations of political liberty. We have no selfish ends to serve. We desire no conquest, no dominion. We seek no indemnities for ourselves, no material compensation for the sacrifices we shall freely make. We are but one of the champions of the rights of mankind. We shall be satisfied when those rights have been made as secure as the faith and the freedom of nations can make them.
#
# Just because we fight without rancor and without selfish object, seeking nothing for ourselves but what we shall wish to share with all free peoples, we shall, I feel confident, conduct our operations as belligerents without passion and ourselves observe with proud punctilio the principles of right and of fair play we profess to be fighting for.
#
# â€¦
#
# ...

# %% [markdown]
# ### Visual Flow

# %% [markdown]
# speech.txt
#      ↓
# TextLoader
#      ↓
# loader.load()
#      ↓
# [Document]
#      ↓
# page_content
#      ↓
# text
#      ↓
# print(text[:1000])

# %% [markdown]
# ### Loading from Multiple docs

# %%
from langchain_community.document_loaders import TextLoader

files = ["ds.txt", "ml.txt"]

documents = []

for file in files:
    loader = TextLoader(file)
    docs = loader.load()
    documents.extend(docs)

print(len(documents))
# Out:
# 2

# %%
print(documents[0].page_content[:500])
# Out:
# Data science is the field that combines statistics, programming, and domain knowledge to extract insights and value from data.
#
# Common Tools & Languages:
# 	Python (pandas, NumPy, scikit-learn, TensorFlow, etc.)
# 	R
# 	SQL
# 	Jupyter Notebooks
# 	Tableau / Power BI
#
# Real-World Applications:
# 	Predicting customer behavior
# 	Recommender systems (like Netflix or Amazon)
# 	Fraud detection
# 	Health analytics
# 	Natural language processing

# %%
print(documents[1].page_content[:5500])
# Out:
# Introduction to Machine Learning
#
# 	Machine learning is a field of artificial intelligence that focuses on developing systems that can learn from and make decisions based on data. Instead of being explicitly programmed to perform a task, these systems improve their performance over time through experience.
#
# Popular Machine Learning Algorithms
#
# 		Linear and logistic regression
# 		Decision trees and random forests
# 		Support Vector Machines (SVM)
# 		Neural networks and deep learning
# 		K-means clustering
# 		Principal Component Analysis (PCA)
#
# Applications of Machine Learning
#
# 	Computer vision and image recognition
# 	Natural language processing
# 	Recommendation systems
# 	Fraud detection
# 	Autonomous vehicles
# 	Medical diagnosis
# 	Financial forecasting

# %% [markdown]
# ### Load All Files in a Folder (Most Common for RAG)

# %%
from langchain_community.document_loaders import DirectoryLoader

loader = DirectoryLoader(
    "docs",
    glob="*.txt"
)

documents = loader.load()

print(len(documents))

print(documents[0].page_content[:500])

print("----")
print(documents[1].page_content[:500])
# Out:
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# libmagic is unavailable but assists in filetype detection. Please consider installing libmagic for better results.
# 2
# Data science is the field that combines statistics, programming, and domain knowledge to extract insights and value from data.
#
# Core Components: Data Collection – Getting data from sources like databases, APIs, web scraping, or sensors.
#
# Data Cleaning – Removing errors, dealing with missing values, normalizing formats.
#
# Exploratory Data Analysis (EDA) – Using statistics and visualizations to understand the data.
#
# Modeling – Using machine learning or statistical models to make predictions or find
# ----
# Introduction to Machine Learning
#
# ...

# %% [markdown]
# ### Using TextLoader inside DirectoryLoader

# %%
from langchain_community.document_loaders import DirectoryLoader, TextLoader

loader = DirectoryLoader(
    "docs",
    glob="*.txt",
    loader_cls=TextLoader
)

documents = loader.load()

print(len(documents))
# Out:
# 2

# %%
print(documents[0].page_content[:500])

print("----")
print(documents[1].page_content[:500])
# Out:
# Data science is the field that combines statistics, programming, and domain knowledge to extract insights and value from data.
#
# Core Components:
# 	Data Collection â€“ Getting data from sources like databases, APIs, web scraping, or sensors.
#
# 	Data Cleaning â€“ Removing errors, dealing with missing values, normalizing formats.
#
# 	Exploratory Data Analysis (EDA) â€“ Using statistics and visualizations to understand the data.
#
# 	Modeling â€“ Using machine learning or statistical models to make predict
# ----
# Introduction to Machine Learning
#
# 	Machine learning is a field of artificial intelligence that focuses on developing systems that can learn from and make decisions based on data. Instead of being explicitly programmed to perform a task, these systems improve their performance over time through experience.
#
# Core Concepts in Machine Learning
# 	Machine learning algorithms can be broadly categorized into several types:
#
# ...

# %% [markdown]
# ### Access Each Document

# %%
for doc in documents:
    print(doc.metadata["source"])
    print("\n")
    print(doc.page_content[:200])
# Out:
# docs\DS.txt
#
#
# Data science is the field that combines statistics, programming, and domain knowledge to extract insights and value from data.
#
# Core Components:
# 	Data Collection â€“ Getting data from sources like dat
# docs\ML.txt
#
#
# Introduction to Machine Learning
#
# 	Machine learning is a field of artificial intelligence that focuses on developing systems that can learn from and make decisions based on data. Instead of being expl

# %% [markdown]
# ---

# %% [markdown]
# ### Read a PDf file

# %% [markdown]
# * It is used to read PDF files and convert them into LangChain Document objects.

# %%
from langchain_community.document_loaders import PyPDFLoader

loader=PyPDFLoader('AI and DATA SCIENCE.pdf')

# %% [markdown]
# * At this stage:
#
#    * The file is not yet read
#
#    *  Only a loader object is created

# %%
docs=loader.load()

docs
# Out:
# [Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-07T05:04:36+05:30', 'author': 'GanapatiRaju Nadimpalli', 'moddate': '2025-07-07T05:04:36+05:30', 'source': 'AI and DATA SCIENCE.pdf', 'total_pages': 11, 'page': 0, 'page_label': '1'}, page_content='AI & DATA SCIENCE USING PYTHON \nIntroduction to AI ML DS , Gen AI and Agentic AI (DEMO) \n• Relationship between AI, ML, DL, NLP, Data Science, Gen AI, Agentic AI \n• Applications for data science \n• Why Python for Data Science \n• AI Tools: Claude/Perplexity/Co Pilot/ChatGPT/Deep Seek \n \nPython Programming \nPython Overview  \n• Installation of Anaconda Python,  \n• Python Features \n• Variables, Operators, Data Types \n• Conditions  \n• Loops \n• Functions \n• Modules, Packages \n• String object, Exercises \n• List object, Exercises, Case study \n• Tuple object, Exercises \n• Dictionary object, Exercises, Case Study \n• Set, Frozenset  \n• Comp
# ...

# %% [markdown]
# * Now LangChain:
#
#     * Opens the PDF
#
#     * Reads each page
#
#     * Converts each page into a Document object

# %%
print(len(docs))        # number of pages
# Out:
# 11

# %%
print(docs[10].page_content[:500])  # first 500 characters from page 1
# Out:
# GEN AI , RAG Vector Databases, AGENTIC AI
# Generative AI and LLMs with Use Cases
# • Gen AI text, Images, Video
# • Creating own Chatbots
# • Gen AI using SQL function calling
# • Gen AI with Word Embeddings and case studies
# • Gemini, Llama, Ollama, gemma , Mistral  etc
# • Vector Databases
# o Chroma DB
# o Faiss,
# o Pinecone
# • Retrieval-Augmented Generation (RAG)
# o Applications of RAG
# • Conversation between Llama/Gemini with Notepad text, PDF, Web  data.
#
# Agentic AI Frameworks
# • AI Agents,

# %%
print(docs[0].metadata)            # metadata for page 2
# Out:
# {'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-07T05:04:36+05:30', 'author': 'GanapatiRaju Nadimpalli', 'moddate': '2025-07-07T05:04:36+05:30', 'source': 'AI and DATA SCIENCE.pdf', 'total_pages': 11, 'page': 0, 'page_label': '1'}

# %% [markdown]
# ### Print Text from All Pages (Very Useful)

# %%
for doc in docs:
    
    print("Page:", doc.metadata["page"] + 1)
    
    print(doc.page_content[:1000])
    
    print("-"*50)
# Out:
# Page: 1
# AI & DATA SCIENCE USING PYTHON
# Introduction to AI ML DS , Gen AI and Agentic AI (DEMO)
# • Relationship between AI, ML, DL, NLP, Data Science, Gen AI, Agentic AI
# • Applications for data science
# • Why Python for Data Science
# • AI Tools: Claude/Perplexity/Co Pilot/ChatGPT/Deep Seek
#
# Python Programming
# Python Overview
# • Installation of Anaconda Python,
# • Python Features
# • Variables, Operators, Data Types
# • Conditions
# • Loops
# • Functions
# • Modules, Packages
# • String object, Exercises
# • List object, Exercises, Case study
# • Tuple object, Exercises
# • Dictionary object, Exercises, Case Study
# • Set, Frozenset
# • Comprehensions
# • List comprehension,
# • Dictionary comprehension.
# • Set Comprehension
#
# • Python File I/O
# • Applications using File IO
# • Exercises
# --------------------------------------------------
# Page: 2
# • Regular expressions
# • Identifiers
# • Quantifiers
# • Lookahead, Lookbehind examples
# • Exercises
#
# ...

# %% [markdown]
# ### Visual Flow

# %% [markdown]
# AI and DATA SCIENCE.pdf
#         ↓
# PyPDFLoader
#         ↓
# loader.load()
#         ↓
# List of Documents
#         ↓
# Page 1 → Document
# Page 2 → Document
# Page 3 → Document

# %% [markdown]
# ### WikipediaLoader

# %%
# ! pip install wikipedia

# %%
from langchain_community.document_loaders import WikipediaLoader

# %%
docs = WikipediaLoader(query="Langchain", load_max_docs=4).load()

# %%
len(docs)

# %%
print(docs)
