# %%
def main():
    print("Hello World")

# %%
if __name__=="__main__":
    main()

# %%
s = input("Enter Number")
print(s)

# %%
s = input()
print(s)

# %%
nums = [1, 2, 3, 4, 5]  
def sq(n):    
    return n*n  

square3 = list(map(sq, nums))
print(square3)

# %% [markdown]
# #### The below print second largest element

# %%
s = list(map(int, input().split()))

list(set(s))[-2]
# Out:
#  2 3 6 6 5
# 5

# %%
n = int(input())
student_marks = {}

for _ in range(n):
    name, *line = input().split()
    scores = list(map(float, line))
    student_marks[name] = scores
    
student_marks

# %% [markdown]
# 3
#
# Krishna 67 68 69
#
# Arjun 70 98 63
#
# Malika 52 56 60
#
# Malika
