# %%
import pandas as pd

data = {
    'account_number': [101, 102, 103, 104, 105],
    'holder_name': ['Ram', 'Krishna', 'Shiva', 'Ganesh', 'Sai'],
    'status': ['active', 'inactive', 'active', 'inactive', 'active']
}

df = pd.DataFrame(data)
df
# Out:
#    account_number holder_name    status
# 0             101         Ram    active
# 1             102     Krishna  inactive
# 2             103       Shiva    active
# 3             104      Ganesh  inactive
# 4             105         Sai    active

# %%
active_accounts = df[df['status'] == 'active']
print(active_accounts)
# Out:
#    account_number holder_name  status
# 0             101         Ram  active
# 2             103       Shiva  active
# 4             105         Sai  active

# %%
inactive_accounts = df[df['status'] == 'inactive']
print(inactive_accounts)
# Out:
#    account_number holder_name    status
# 1             102     Krishna  inactive
# 3             104      Ganesh  inactive

# %%
df.query("status == 'active'")
# Out:
#    account_number holder_name  status
# 0             101         Ram  active
# 2             103       Shiva  active
# 4             105         Sai  active

# %%
df.query("status == 'inactive'")
# Out:
#    account_number holder_name    status
# 1             102     Krishna  inactive
# 3             104      Ganesh  inactive

# %%
df[df['status'].isin(['active'])]
# Out:
#    account_number holder_name  status
# 0             101         Ram  active
# 2             103       Shiva  active
# 4             105         Sai  active

# %%
df[df['status'].isin(['active'])]
# Out:
#    account_number holder_name  status
# 0             101         Ram  active
# 2             103       Shiva  active
# 4             105         Sai  active
