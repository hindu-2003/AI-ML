# %% [markdown]
# ## SVM on cancer data

# %% [markdown]
# sklearn.svm.SVC (C=1.0, kernel= ‘rbf’, degree=3)

# %% [markdown]
# C parameter : Keeping large values of C will indicate the SVM model to choose a smaller margin hyperplane.
#
#               Small value of C will indicate the SVM model to choose a larger margin hyperplane.
#
# kernel parameter : It is the kernel type to be used in SVM model building.
#
#                    It can be ‘linear’, ‘rbf’, ‘poly’, or ‘sigmoid’. The default value of kernel is ‘rbf’.
#
# degree parameter : It’s only considered in the case of polynomial kernel.
#
#                    It is the degree of the polynomial kernel function. The default value of degree is 3.
#
# Gamma parameter :  Gamma decides that how much curvature we want in a decision boundary.
#
#                    Gamma high means more curvature.
#
#                    Gamma low means less curvature.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("cancer.csv")

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
# Convert diagnosis M/B → 1/0
df["diagnosis"] = df["diagnosis"].map({"M": 1, "B": 0})

# %%
# Drop id column

df = df.drop("id", axis=1)

# %%
# Split features and label
X = df.drop("diagnosis", axis=1)

y = df["diagnosis"]

# %%
X
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
# TRAIN / TEST SPLIT

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=109
)

# %%
# Scale features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# SVM – Linear

clf_linear = SVC(kernel='linear')
clf_linear.fit(X_train, y_train)
pred_linear = clf_linear.predict(X_test)

print("\n=== Linear Kernel ===")
print("Accuracy:", accuracy_score(y_test, pred_linear))
print("Precision:", precision_score(y_test, pred_linear))
print("Recall:", recall_score(y_test, pred_linear))
print(confusion_matrix(y_test, pred_linear))
print(classification_report(y_test, pred_linear))
# Out:
# === Linear Kernel ===
# Accuracy: 0.9883040935672515
# Precision: 1.0
# Recall: 0.9682539682539683
# [[108   0]
#  [  2  61]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       108
#            1       1.00      0.97      0.98        63
#
#     accuracy                           0.99       171
#    macro avg       0.99      0.98      0.99       171
# weighted avg       0.99      0.99      0.99       171

# %%
# SVM – Polynomial

clf_poly = SVC(kernel='poly')
clf_poly.fit(X_train, y_train)
pred_poly = clf_poly.predict(X_test)

print("\n=== Polynomial Kernel ===")
print("Accuracy:", accuracy_score(y_test, pred_poly))
print("Precision:", precision_score(y_test, pred_poly))
print("Recall:", recall_score(y_test, pred_poly))
# Out:
# === Polynomial Kernel ===
# Accuracy: 0.9005847953216374
# Precision: 1.0
# Recall: 0.7301587301587301

# %%
# -------------------------------
# SVM – RBF
# -------------------------------
clf_rbf = SVC(kernel='rbf')
clf_rbf.fit(X_train, y_train)
pred_rbf = clf_rbf.predict(X_test)

print("=== RBF Kernel ===")
print("Accuracy:", accuracy_score(y_test, pred_rbf))
# Out:
# === RBF Kernel ===
# Accuracy: 0.9824561403508771

# %%
# SVM – Sigmoid

clf_sig = SVC(kernel='sigmoid')
clf_sig.fit(X_train, y_train)
pred_sig = clf_sig.predict(X_test)

print("\n=== Sigmoid Kernel ===")
print("Accuracy:", accuracy_score(y_test, pred_sig))
# Out:
# === Sigmoid Kernel ===
# Accuracy: 0.9707602339181286

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    classification_report, confusion_matrix
)
from sklearn.preprocessing import StandardScaler


df = pd.read_csv("cancer.csv")


# Convert diagnosis M/B → 1/0
df["diagnosis"] = df["diagnosis"].map({"M": 1, "B": 0})

# Drop id column
df = df.drop("id", axis=1)

# Split features and label
X = df.drop("diagnosis", axis=1)
y = df["diagnosis"]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=109
)

# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)


def evaluate_model(name, y_true, y_pred):
    print(f"\n===== {name} Kernel =====")
    print("Accuracy :", accuracy_score(y_true, y_pred))
    print("Precision:", precision_score(y_true, y_pred))
    print("Recall   :", recall_score(y_true, y_pred))
    print("\nConfusion Matrix:\n", confusion_matrix(y_true, y_pred))
    print("\nClassification Report:\n", classification_report(y_true, y_pred))


# ---------------------------------------------
# SVM – Linear
# ---------------------------------------------
clf_linear = SVC(kernel='linear')
clf_linear.fit(X_train, y_train)
pred_linear = clf_linear.predict(X_test)
evaluate_model("Linear", y_test, pred_linear)


# ---------------------------------------------
# SVM – Polynomial
# ---------------------------------------------
clf_poly = SVC(kernel='poly', degree=3)  # degree can be tuned
clf_poly.fit(X_train, y_train)
pred_poly = clf_poly.predict(X_test)
evaluate_model("Polynomial", y_test, pred_poly)


# ---------------------------------------------
# SVM – RBF
# ---------------------------------------------
clf_rbf = SVC(kernel='rbf')
clf_rbf.fit(X_train, y_train)
pred_rbf = clf_rbf.predict(X_test)
evaluate_model("RBF", y_test, pred_rbf)


# ---------------------------------------------
# SVM – Sigmoid
# ---------------------------------------------
clf_sig = SVC(kernel='sigmoid')
clf_sig.fit(X_train, y_train)
pred_sig = clf_sig.predict(X_test)
evaluate_model("Sigmoid", y_test, pred_sig)
# Out:
# ===== Linear Kernel =====
# Accuracy : 0.9883040935672515
# Precision: 1.0
# Recall   : 0.9682539682539683
#
# Confusion Matrix:
#  [[108   0]
#  [  2  61]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       108
#            1       1.00      0.97      0.98        63
#
#     accuracy                           0.99       171
#    macro avg       0.99      0.98      0.99       171
# weighted avg       0.99      0.99      0.99       171
#
#
# ===== Polynomial Kernel =====
# Accuracy : 0.9005847953216374
# Precision: 1.0
# Recall   : 0.7301587301587301
#
# Confusion Matrix:
#  [[108   0]
#  [ 17  46]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93       108
#            1       1.00      0.73      0.84        63
#
#     accuracy                           0.90       171
# ...
