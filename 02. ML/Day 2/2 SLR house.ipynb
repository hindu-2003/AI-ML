# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
house_data = pd.read_csv('house.csv')

# %%
house_data.shape
# Out:
# (1459, 2)

# %%
house_data.head()
# Out:
#    GrLivArea  SalePrice
# 0       1262     181500
# 1       1786     223500
# 2       1717     140000
# 3       2198     250000
# 4       1362     143000

# %%
house_data.columns
# Out:
# Index(['GrLivArea', 'SalePrice'], dtype='object')

# %%
house_data.GrLivArea.hist()
plt.show()

# %%
house_data.SalePrice.hist()
plt.show()

# %%
plt.scatter(house_data.GrLivArea, house_data.SalePrice, alpha=0.9)
plt.show()

# %%
x=house_data.iloc[:,0:1]

y=house_data.iloc[:,1]

# %%
x.head(5)
# Out:
#    GrLivArea
# 0       1262
# 1       1786
# 2       1717
# 3       2198
# 4       1362

# %%
y.head(5)
# Out:
# 0    181500
# 1    223500
# 2    140000
# 3    250000
# 4    143000
# Name: SalePrice, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
model2 = LinearRegression()

# %%
model2 = model2.fit(x, y)

# %%
r_sq = model2.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.502112430197658

# %%
print('intercept:', model2.intercept_)
# Out:
# intercept: 18569.341740386473

# %%
print('slope:', model2.coef_)
# Out:
# slope: [107.12710281]

# %%
y_prd = model2.intercept_ + (model2.coef_) * 1700
print(y_prd)
# Out:
# [200685.41651165]

# %%
y_pred2 = model2.predict(x)
print(y_pred2)
# Out:
# [153763.74548235 209898.34735302 202506.57725936 ... 269246.76230789
#  134052.35856593 153120.98286551]

# %%
import sklearn.metrics as metrics
mae = metrics.mean_absolute_error(y, y_pred2)
mse = metrics.mean_squared_error(y, y_pred2)
rmse = np.sqrt(mse) # or mse**(0.5)  
r2 = metrics.r2_score(y,y_pred2)

print("Results of sklearn.metrics:")
print("MAE:",mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R-Squared:", r2)
# Out:
# Results of sklearn.metrics:
# MAE: 37659.65295937348
# MSE: 3141964118.7574162
# RMSE: 56053.22576585059
# R-Squared: 0.502112430197658

# %%
import pandas as pd

uk = pd.read_csv('houseuk.csv')
print(uk)
# Out:
#    GrLivArea
# 0       1700

# %%
y_pred3 = model2.predict(uk)
print(y_pred3)
# Out:
# [200685.41651165]
