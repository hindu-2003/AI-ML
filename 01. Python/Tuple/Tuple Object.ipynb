# %%
print('-------tuple-------')
data=(10,20,'ram',56.8)  
data2="a",10,20.9  

print (data)  
print(data2)

print(type(data2))
# Out:
# -------tuple-------
# (10, 20, 'ram', 56.8)
# ('a', 10, 20.9)
# <class 'tuple'>

# %%
tuple1=()
print(tuple1)
# Out:
# ()

# %%
tuple11=tuple()
print(tuple11)
# Out:
# ()

# %%
print('-------tuple with single element-------')

tuple2=(10,)
print(type(tuple2))
# Out:
# -------tuple with single element-------
# <class 'tuple'>

# %%
tuple2=(10.5)
print(type(tuple2))
# Out:
# <class 'float'>

# %%
print('-------nested tuple-------')
tupl1='a','mahesh',10.56  
tupl2=tupl1,(10,20,30) 

print (tupl1)
print (tupl2)
# Out:
# -------nested tuple-------
# ('a', 'mahesh', 10.56)
# (('a', 'mahesh', 10.56), (10, 20, 30))

# %%
print('-----accessing tuple-------')
data3=(0,1,2,3,4)  

print (data3[0])
print (data3[0:2])
# Out:
# -----accessing tuple-------
# 0
# (0, 1)

# %%
data4=('x','y','z')

print (data4[-3:-1])
# Out:
# ('x', 'y')

# %%
print (data4[-1:-3])
# Out:
# ()

# %%
#print (data3[1.1])

# %%
print('-----adding tuple-------')
data5=(1,2,3,4)  
data6=('x','y','z')  

data7=data5 + data6  

print (data7)
# Out:
# -----adding tuple-------
# (1, 2, 3, 4, 'x', 'y', 'z')

# %%
data5=(1,2,3,4)  
data6=(1,)

data7 = data5 + data6  

print (data7)
# Out:
# (1, 2, 3, 4, 1)

# %%
print('-----replicating-------')
tuple4=(10,20,30)

print (tuple4 * 2)
# Out:
# -----replicating-------
# (10, 20, 30, 10, 20, 30)

# %%
print('-----tuple Slicing-------')
data8=(1,2,4,5,7)  
print(data8[0:2])
# Out:
# -----tuple Slicing-------
# (1, 2)

# %%
print (data8[:-1])
# Out:
# (1, 2, 4, 5)

# %%
print (data8[-1:])
# Out:
# (7,)

# %%
data8[::-1]
# Out:
# (7, 5, 4, 2, 1)

# %%
print('-----deleting elements------')
data10=(10,20,'rahul',40.6,'z')  
print (data10)
del (data10)

#print(data10)
# Out:
# -----deleting elements------
# (10, 20, 'rahul', 40.6, 'z')

# %% [markdown]
# ### index count

# %%
t2=(10,'savik',40.6,'z',40.6)  

print(t2.index(40.6))
# Out:
# 2

# %%
print(t2.index('a'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(t2.index('a'))
#
# ValueError: tuple.index(x): x not in tuple

# %%
t2=(10,'savik',40.6,10,'z')  

print(t2.count(10))
# Out:
# 2

# %% [markdown]
# ### Unpack

# %%
a, b, c = (10, 20, 30)
print(a,b,c)
# Out:
# 10 20 30

# %%
a,b  = (10, 20, 30)

print(a,b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 a,b  = (10, 20, 30)
#       3 print(a,b)
#
# ValueError: too many values to unpack (expected 2)

# %%
a = (10, 20, 30)

print(a)
# Out:
# (10, 20, 30)
